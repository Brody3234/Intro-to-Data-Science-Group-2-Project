# %%
# Install required packages if missing
import sys
# !{sys.executable} -m pip install pandas numpy matplotlib seaborn scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
BASE_DIR = os.getcwd()
if not os.path.isdir('Data') and os.path.isdir('../Data'):
    os.chdir('..')
    BASE_DIR = os.getcwd()
DATA_DIR = os.path.join(BASE_DIR, 'Data')
print('Working directory:', BASE_DIR)
print('Data directory:', DATA_DIR)

# %%
try:
    from sklearn.metrics import r2_score, mean_squared_error
    preds = model.predict(X_test)
    print('R2 Score:', r2_score(y_test, preds))
    print('RMSE:', mean_squared_error(y_test, preds, squared=False))
except Exception as e:
    print('Model evaluation skipped:', e)

# %% [markdown]
# ## Key Findings (Summary)
#
# Population, income, and housing supply indicators show the strongest association with home price trends in the cleaned dataset. Tree-based models typically capture nonlinear relationships better than linear regression.
